# %% [markdown]
# # PUBG Finish Placement Prediction

# %% [markdown]
# A model which predicts players' finishing placement based on their final stats, on a scale from 1 (first place) to 0 (last place).

# %% [markdown]
# <img src="Images/1.jpg" alt="drawing" width="800px"/>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train_V2.csv", nrows = 100000)

# %%
df.describe()
# Out:
#              assists         boosts    damageDealt          DBNOs  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.233240       1.119330     130.659763       0.653720
# std         0.588475       1.724819     170.166440       1.143277
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000      83.850000       0.000000
# 75%         0.000000       2.000000     185.900000       1.000000
# max        13.000000      21.000000    3725.000000      32.000000
#
#        headshotKills          heals      killPlace     killPoints  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.222920       1.372880      47.597980     504.549130
# std         0.586711       2.669875      27.483175     626.860022
# min         0.000000       0.000000       1.000000       0.000000
# 25%         0.000000       0.000000      24.000000       0.000000
# 50%         0.000000       0.000000      48.000000       0.000000
# 75%         0.000000       2.000000      71.000000    1170.000000
# max        17.000000      47.000000     100.000000    2152.000000
#
#                kills    killStreaks  ...       revives   rideDistance  \
# count  100000.000000  100000.000000  ...  100000.00000  100000.000000
# mean        0.923440       0.543630  ...       0.16230     603.976697
# std         1.549013       0.712897  ...       0.46139    1490.630207
# min         0.000000       0.000000  ...       0.00000       0.000000
# 25%         0.000000       0.000000  ...       0.00000       0.000000
# 50%         0.000000       0.000000  ...       0.00000       0.000000
# 75%         1.000000       1.000000  ...       0.00000       0.027725
# max        35.000000      10.000000  ...       9.00000   28450.000000
#
#            roadKills   swimDistance      teamKills  vehicleDestroys  \
# count  100000.000000  100000.000000  100000.000000     100000.00000
# mean        0.003940       4.431591       0.023860          0.00759
# std         0.083693      29.088230       0.165864          0.09018
# min         0.000000       0.000000       0.000000          0.00000
# 25%         0.000000       0.000000       0.000000          0.00000
# 50%         0.000000       0.000000       0.000000          0.00000
# 75%         0.000000       0.000000       0.000000          0.00000
# max         6.000000    1220.000000       4.000000          4.00000
#
#         walkDistance  weaponsAcquired      winPoints   winPlacePerc
# count  100000.000000    100000.000000  100000.000000  100000.000000
# mean     1158.852715         3.674470     606.340150       0.473661
# std      1185.515461         2.461658     739.520887       0.307770
# min         0.000000         0.000000       0.000000       0.000000
# 25%       156.000000         2.000000       0.000000       0.200000
# 50%       694.800000         3.000000       0.000000       0.461500
# 75%      1981.000000         5.000000    1495.000000       0.741900
# max     13530.000000        61.000000    1972.000000       1.000000
#
# [8 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 29 columns):
# Id                 100000 non-null object
# groupId            100000 non-null object
# matchId            100000 non-null object
# assists            100000 non-null int64
# boosts             100000 non-null int64
# damageDealt        100000 non-null float64
# DBNOs              100000 non-null int64
# headshotKills      100000 non-null int64
# heals              100000 non-null int64
# killPlace          100000 non-null int64
# killPoints         100000 non-null int64
# kills              100000 non-null int64
# killStreaks        100000 non-null int64
# longestKill        100000 non-null float64
# matchDuration      100000 non-null int64
# matchType          100000 non-null object
# maxPlace           100000 non-null int64
# numGroups          100000 non-null int64
# rankPoints         100000 non-null int64
# revives            100000 non-null int64
# rideDistance       100000 non-null float64
# roadKills          100000 non-null int64
# swimDistance       100000 non-null float64
# teamKills          100000 non-null int64
# vehicleDestroys    100000 non-null int64
# walkDistance       100000 non-null float64
# weaponsAcquired    100000 non-null int64
# winPoints          100000 non-null int64
# winPlacePerc       100000 non-null float64
# dtypes: float64(6), int64(19), object(4)
# memory usage: 22.1+ MB

# %% [markdown]
# ## A description of the attributes
#
# - groupId - Integer ID to identify a group within a match. If the same group of players plays in different matches, they will have a different groupId each time.
# - matchId - Integer ID to identify match. There are no matches that are in both the training and testing set.
# - assists - Number of enemy players this player damaged that were killed by teammates.
# - boosts - Number of boost items used.
# - damageDealt - Total damage dealt. Note: Self inflicted damage is subtracted.
# - DBNOs - Number of enemy players knocked.
# - headshotKills - Number of enemy players killed with headshots.
# - heals - Number of healing items used.
# - killPlace - Ranking in match of number of enemy players killed.
# - killPoints - Kills-based external ranking of player. (Think of this as an Elo ranking where only kills matter.)
# - kills - Number of enemy players killed.
# - killStreaks - Max number of enemy players killed in a short amount of time.
# - longestKill - Longest distance between player and player killed at time of death. This may be misleading, as downing a - player and driving away may lead to a large longestKill stat.
# - maxPlace - Worst placement we have data for in the match. This may not match with numGroups, as sometimes the data skips over placements.
# - numGroups - Number of groups we have data for in the match.
# - revives - Number of times this player revived teammates.
# - rideDistance - Total distance traveled in vehicles measured in meters.
# - roadKills - Number of kills while in a vehicle.
# - swimDistance - Total distance traveled by swimming measured in meters.
# - teamKills - Number of times this player killed a teammate.
# - vehicleDestroys - Number of vehicles destroyed.
# - walkDistance - Total distance traveled on foot measured in meters.
# - weaponsAcquired - Number of weapons picked up.
# - winPoints - Win-based external ranking of player. (Think of this as an Elo ranking where only winning matters.)
# - winPlacePerc - The target of prediction. This is a percentile winning placement, where 1 corresponds to 1st place, and 0 corresponds to last place in the match. It is calculated off of maxPlace, not numGroups, so it is possible to have missing chunks in a match.

# %% [markdown]
# # Preprocessing

# %%
df.isnull().sum()
# Out:
# Id                 0
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       0
# dtype: int64

# %% [markdown]
# As it can be seen that the attribute 'winPlacePrec' has a single null value.

# %%
index = df[df['winPlacePerc'].isnull()].index.tolist()
df.loc[index, 'numGroups']
# Out:
# Series([], Name: numGroups, dtype: int64)

# %% [markdown]
# It can be seen that this match has only one player. This can be thought of an illegal match and hence we remove this row.

# %% [markdown]
# <img src="Images/2.png" alt="drawing" width="800px"/>

# %%
df.drop(index, inplace=True)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Kills, Players knocked down and Assists

# %% [markdown]
# <img src="Images/6.jpg" alt="drawing" width="800px"/>

# %%
data = df.copy()
data.loc[data['kills'] > data['kills'].quantile(0.99)] = '8+'
plt.figure(figsize=(15,10))
sns.countplot(data['kills'].astype('str').sort_values())
plt.title("Kill Count",fontsize=15)
plt.show()

# %%
kills = df.copy()

kills['killsCategories'] = pd.cut(kills['kills'], [-1, 0, 2, 5, 10, 60], labels=['0_kills','1-2_kills', '3-5_kills', '6-10_kills', '10+_kills'])

plt.figure(figsize=(15,8))
sns.boxplot(x="killsCategories", y="winPlacePerc", data=kills)
plt.show()

# %%
data = df.copy()
data.loc[data['DBNOs'] > data['DBNOs'].quantile(0.99)] = '8+'
plt.figure(figsize=(15,10))
sns.countplot(data['DBNOs'].astype('str').sort_values())
plt.title("Knocked Players Count",fontsize=15)
plt.show()

# %%
knocked = df.copy()

knocked['knockedCategories'] = pd.cut(knocked['DBNOs'], [-1, 0, 2, 5, 10, 60], labels=['0_knocks','1-2_knocks', '3-5_knocks', '6-10_knocks', '10+_knocks'])

plt.figure(figsize=(15,8))
sns.boxplot(x="knockedCategories", y="winPlacePerc", data=knocked)
plt.show()

# %%
data = df.copy()
data.loc[data['assists'] > data['assists'].quantile(0.99)] = '4+'
plt.figure(figsize=(15,10))
sns.countplot(data['assists'].astype('str').sort_values())
plt.title("Assists Count",fontsize=15)
plt.show()

# %%
assists = df.copy()

assists['assistsCategories'] = pd.cut(assists['assists'], [-1, 0, 2, 5, 10], labels=['0_assists','1-2_assists', '3-5_assists', '5+_assists'])

plt.figure(figsize=(15,8))
sns.boxplot(x="assistsCategories", y="winPlacePerc", data=assists)
plt.show()

# %% [markdown]
# ## Distance Travelled : Walk distance, Ride distance

# %% [markdown]
# <img src="Images/4.png" alt="drawing" width="800px"/>

# %%
x = df.walkDistance
sns.distplot(x)

# %%
plot = df.plot(x='walkDistance', y='winPlacePerc', style='.')
y_label = plot.set_ylabel('winPlacePerc')

# %%
x = df.rideDistance
sns.distplot(x)

# %%
plot = df.plot(x='rideDistance', y='winPlacePerc', style='.')
y_label = plot.set_ylabel('winPlacePerc')

# %% [markdown]
# ### Heals and Boosts

# %% [markdown]
# <img src="Images/5.jpg" alt="drawing" width="800px"/>

# %%
data = df.copy()

f,ax1 = plt.subplots(figsize =(20,10))
sns.pointplot(x='heals',y='winPlacePerc',data=data,color='green',alpha=0.8)
sns.pointplot(x='boosts',y='winPlacePerc',data=data,color='blue',alpha=0.8)
plt.text(4,0.6,'Heals',color='lime',fontsize = 17)
plt.text(4,0.55,'Boosts',color='blue',fontsize = 17)
plt.xlabel('Number of heal/boost items',fontsize = 15)
plt.ylabel('Win Percentage',fontsize = 15)
plt.title('Heals vs Boosts',fontsize = 15)
plt.grid()
plt.show()

# %% [markdown]
# ## Weapons Acquired

# %% [markdown]
# <img src="Images/7.jpg" alt="drawing" width="800px"/>

# %%
x = df.weaponsAcquired
sns.distplot(x)

# %%
plot = df.plot(x='weaponsAcquired', y='winPlacePerc', style='.')
y_label = plot.set_ylabel('winPlacePerc')

# %% [markdown]
# ## Correlation Matrix

# %% [markdown]
# <img src="Images/8.png" alt="drawing" width="800px"/>

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col1 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col2 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col3 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col4 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col5 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col6 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col7 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col8 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col9 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col10 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col11 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col12 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col13 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col14 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col15 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col16 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col17 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col18 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col19 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col20 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col21 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col22 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col23 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow0_col24 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col0 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col2 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col3 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col4 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col5 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col6 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col7 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col8 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col9 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col10 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col11 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col12 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col13 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col14 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col15 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col16 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col17 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col18 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col19 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col20 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col21 {
#             background-color:  #f18f71;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col22 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col23 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow1_col24 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow2_col0 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow2_col1 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow2_col3 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow2_col4 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow2_col5 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow2_col6 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow2_col7 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow2_col8 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_5b87d460_0e9d_11ea_a957_07e99dc7973crow2_col9 {
#             background-color:  #e67259;

# %%
k = 7
f,ax = plt.subplots(figsize=(11, 11))
cols = df.corr().nlargest(k, 'winPlacePerc')['winPlacePerc'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values, cmap='coolwarm')
plt.show()
